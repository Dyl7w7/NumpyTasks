# %%
import pandas as pnd
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15616\1878557931.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pnd

# %%
plano = pnd.read_csv('CalificacionesTXT.csv', sep= ',', encoding='ISO-8859-1')

# %%
plano
# Out:
#     ITEM   NOMBRES   APELLIDOS        Programa     Genero Matematicas  \
# 0      1      Juan     GarcÃ­a    Contabilidad  Masculino        1,66
# 1      2    MarÃ­a      PÃ©rez        Mercadeo   Femenino        3,21
# 2      3     Pedro  FernÃ¡ndez        Sistemas  Masculino        3,10
# 3      4       Ana    SÃ¡nchez  Administracion   Femenino         NaN
# 4      5      Luis   GonzÃ¡lez           Salud  Masculino        2,91
# 5      6    LucÃ­a   MartÃ­nez           Salud   Femenino        3,95
# 6      7     Diego      LÃ³pez  Administracion  Masculino        4,20
# 7      8  Fernanda      Torres        Sistemas   Femenino        4,08
# 8      9    Miguel      Flores        Mercadeo  Masculino        4,06
# 9     10  Carolina  HernÃ¡ndez    Contabilidad   Femenino        2,55
# 10    11    SofÃ­a       DÃ­az    Contabilidad   Femenino        1,79
# 11    12    Javier      Romero        Mercadeo  Masculino         NaN
# ...

# %%
plano.head()
# Out:
#    ITEM NOMBRES   APELLIDOS        Programa     Genero Matematicas EspaÃ±ol  \
# 0     1    Juan     GarcÃ­a    Contabilidad  Masculino        1,66     2,19
# 1     2  MarÃ­a      PÃ©rez        Mercadeo   Femenino        3,21     2,54
# 2     3   Pedro  FernÃ¡ndez        Sistemas  Masculino        3,10     3,11
# 3     4     Ana    SÃ¡nchez  Administracion   Femenino         NaN     2,50
# 4     5    Luis   GonzÃ¡lez           Salud  Masculino        2,91     2,59
#
#   Ciencias Idiomas
# 0     3,56    2,58
# 1     1,98    3,76
# 2     2,62    2,42
# 3     3,66    1,93
# 4     2,45     NaN

# %%
plano.tail()
# Out:
#     ITEM NOMBRES APELLIDOS      Programa     Genero Matematicas EspaÃ±ol  \
# 15    16   Pedro    LÃ³pez  Contabilidad  Masculino        4,08     1,68
# 16    17     Ana    Torres      Mercadeo   Femenino        4,06     3,64
# 17    18    Luis    Flores      Sistemas  Masculino        2,55     3,75
# 18    19  LucÃ­a    GÃ³mez      Sistemas   Femenino        1,79     3,94
# 19    20  Alvaro     Perez      Sistemas  Masculino        4,05        5
#
#    Ciencias Idiomas
# 15     4,16    2,94
# 16     4,31    3,28
# 17     1,84    3,17
# 18     3,70    2,16
# 19      3,7       4

# %%
plano.describe()
# Out:
#            ITEM
# count  20.00000
# mean   10.50000
# std     5.91608
# min     1.00000
# 25%     5.75000
# 50%    10.50000
# 75%    15.25000
# max    20.00000

# %%
plano.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ITEM         20 non-null     int64
#  1   NOMBRES      20 non-null     object
#  2   APELLIDOS    20 non-null     object
#  3   Programa     20 non-null     object
#  4   Genero       20 non-null     object
#  5   Matematicas  18 non-null     object
#  6   EspaÃ±ol     20 non-null     object
#  7   Ciencias     19 non-null     object
#  8   Idiomas      18 non-null     object
# dtypes: int64(1), object(8)
# memory usage: 1.5+ KB

# %%
plano.dropna()
# Out:
#     ITEM   NOMBRES   APELLIDOS        Programa     Genero Matematicas  \
# 0      1      Juan     GarcÃ­a    Contabilidad  Masculino        1,66
# 1      2    MarÃ­a      PÃ©rez        Mercadeo   Femenino        3,21
# 2      3     Pedro  FernÃ¡ndez        Sistemas  Masculino        3,10
# 5      6    LucÃ­a   MartÃ­nez           Salud   Femenino        3,95
# 6      7     Diego      LÃ³pez  Administracion  Masculino        4,20
# 7      8  Fernanda      Torres        Sistemas   Femenino        4,08
# 9     10  Carolina  HernÃ¡ndez    Contabilidad   Femenino        2,55
# 10    11    SofÃ­a       DÃ­az    Contabilidad   Femenino        1,79
# 12    13   Valeria        Ruiz        Sistemas   Femenino        3,27
# 13    14     Elena    Ãlvarez  Administracion   Femenino        2,43
# 14    15   AndrÃ©s      GÃ³mez           Salud  Masculino        3,59
# 15    16     Pedro      LÃ³pez    Contabilidad  Masculino        4,08
# ...

# %%
planofinal = plano.dropna()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 plano.to_csv('Calificacionestxt.csv', sep=', ')
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
